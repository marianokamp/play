# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install -q fastai

# %%
from fastai.vision import *

# %% [markdown]
# - carol
# - kilt
# url_formal_attire = 'https://www.google.com/search?biw=1440&bih=794&tbs=itp%3Aphoto&tbm=isch&sa=1&ei=XnpLXO33MaXAlAaKl4CIAQ&q=men+formal+attire&oq=men+formal+attire&gs_l=img.3..0l6j0i30l3j0i5i30.54730095.54730930..54731211...0.0..0.57.320.6......1....1..gws-wiz-img.......0i8i30.kyHk0HYkVLw'
# - fanatic
# url_sports_attire = 'https://www.google.com/search?biw=1440&bih=794&tbs=itp%3Aphoto&tbm=isch&sa=1&ei=hntLXJbRNajikgWx_734BA&q=men+sports+attire+-gazette+-fila+-soliddrop+-thegoodtrade&oq=men+sports+attire+-gazette+-fila+-soliddrop+-thegoodtrade&gs_l=img.3...12428.14979..15220...0.0..0.63.669.14......1....1..gws-wiz-img.bEAOsOyA6EA'

# %%
# !mkdir -p data/formal
# !mkdir -p data/sports

# %%
image_downloads = [('formal_attire.txt', 'images/formal'), ('sports_attire.txt', 'images/sports')]
for (urls, dest) in image_downloads:
    download_images(urls=urls, dest=dest, max_workers=5, max_pics=5000)
    verify_images(dest, delete=True, max_size=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='570' class='' max='570', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [570/570 00:43<00:00]
#     </div>
# Error https://resources.mandmdirect.com/Images/_default/t/b/3/tb3965_1_large.jpg HTTPSConnectionPool(host='resources.mandmdirect.com', port=443): Read timed out. (read timeout=4)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='568' class='' max='568', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [568/568 00:05<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='images/formal/00000134.jpg'>
# cannot identify image file <_io.BufferedReader name='images/formal/00000416.png'>
# cannot identify image file <_io.BufferedReader name='images/formal/00000552.jpg'>
# cannot identify image file <_io.BufferedReader name='images/formal/00000417.jpg'>
# cannot identify image file <_io.BufferedReader name='images/formal/00000436.jpg'>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='581' class='' max='581', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [581/581 03:13<00:00]
#     </div>
# Error https://resources.mandmdirect.com/Images/_default/u/j/1/uj1496_1_large.jpg HTTPSConnectionPool(host='resources.mandmdirect.com', port=443): Read timed out. (read timeout=4)
# Error https://resources.mandmdirect.com/Images/_default/a/d/1/ad15831_1_large.jpg HTTPSConnectionPool(host='resources.mandmdirect.com', port=443): Read timed out. (read timeout=4)
# Error https://images.footballfanatics.com/FFImage/thumb.aspx?i=/productimages/_3378000/ff_3378207-958dd6dd165641232b30a_full.jpg&w=340 HTTPSConnectionPool(host='images.footballfanatics.com', port=443): Read timed out. (read timeout=4)
# Error https://images.footballfanatics.com/FFImage/thumb.aspx?i=/productimages/_2327000/ff_2327607_full.jpg&w=340 HTTPSConnectionPool(host='images.footballfanatics.com', port=443): Read timed out. (read timeout=4)
# Error https://resources.mandmdirect.com/Images/_default/c/n/1/cn1442_1_large.jpg HTTPSConnectionPool(host='resources.mandmdirect.com', port=443): Read timed out. (read timeout=4)
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_2327000/ff_2327553_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error https://shop.buccaneers.com/mediacontent//thumb_300/199510.JPG HTTPSConnectionPool(host='shop.buccaneers.com', port=443): Read timed out. (read timeout=4)
# Error https://lf.lids.com/hwl?set=sku[21001181],c[2],w[400],h[300]&call=url[file:product] HTTPSConnectionPool(host='lf.lids.com', port=443): Read timed out. (read timeout=4)
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_2942000/ff_2942688_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2907000/ff_2907625_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2907000/ff_2907625_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3229000/ff_3229364_full.jpg&w=360&q=80 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3229000/ff_3229364_full.jpg&w=360&q=80 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2985000/ff_2985967_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2985000/ff_2985967_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3071000/ff_3071933_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3071000/ff_3071933_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error https://resources.mandmdirect.com/Images/_default/a/d/1/ad15830_1_large.jpg HTTPSConnectionPool(host='resources.mandmdirect.com', port=443): Read timed out. (read timeout=4)
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?ans=v1&i=/productimages/_2327000/ff_2327604_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_3056000/ff_3056779_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2617000/ff_2617140c_full.jpg&w=360&q=80 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2617000/ff_2617140c_full.jpg&w=360&q=80 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error https://lf.lids.com/hwl?set=sku[20967457],c[2],w[400],h[300]&call=url[file:product] HTTPSConnectionPool(host='lf.lids.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3050000/ff_3050808c_full.jpg&w=360&q=80 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3050000/ff_3050808c_full.jpg&w=360&q=80 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2494000/ff_2494828c_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2494000/ff_2494828c_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_2998000/ff_2998275_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_1733000/ff_1733776_xl.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2487000/ff_2487998c_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2487000/ff_2487998c_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3278000/ff_3278792c_full.jpg&w=360&q=80 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3278000/ff_3278792c_full.jpg&w=360&q=80 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error http://images.footballfanatics.com/partners/secstore/FOUNDATIONS/Graphics/SEC_MEN.jpg HTTPConnectionPool(host='images.footballfanatics.com', port=80): Max retries exceeded with url: /partners/secstore/FOUNDATIONS/Graphics/SEC_MEN.jpg (Caused by ReadTimeoutError("HTTPConnectionPool(host='images.footballfanatics.com', port=80): Read timed out. (read timeout=4)",))
# Error https://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productimages/_2920000/ff_2920511_full.jpg&w=340 HTTPSConnectionPool(host='fanatics.frgimages.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3153000/ff_3153531c_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3153000/ff_3153531c_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error https://images.footballfanatics.com/FFImage/thumb.aspx?i=/productimages/_2410000/ff_2410582_full.jpg&w=340 HTTPSConnectionPool(host='images.footballfanatics.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_3079000/ff_3079816-49b3e0e38f1a315f4553_full.jpg&w=340 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_3079000/ff_3079816-49b3e0e38f1a315f4553_full.jpg&w=340 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
# Error https://i.shgcdn.com/7407f720-7893-42ee-b3ad-37a4a4b4f3b2/-/format/auto/-/preview/3000x3000/-/quality/lighter/ HTTPSConnectionPool(host='i.shgcdn.com', port=443): Read timed out. (read timeout=4)
# Error http://fanatics.frgimages.com/FFImage/thumb.aspx?i=/productImages/_2985000/ff_2985984_full.jpg&w=360&q=80 HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Max retries exceeded with url: /FFImage/thumb.aspx?i=/productImages/_2985000/ff_2985984_full.jpg&w=360&q=80 (Caused by ReadTimeoutError("HTTPConnectionPool(host='fanatics.frgimages.com', port=80): Read timed out. (read timeout=4)",))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='515' class='' max='515', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [515/515 00:04<00:00]
#     </div>
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/PIL/Image.py:984: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# cannot identify image file <_io.BufferedReader name='images/sports/00000101.jpg'>
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/PIL/Image.py:931: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='images/sports/00000069.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000281.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000079.jpg'>
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/PIL/Image.py:931: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='images/sports/00000478.png'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000331.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000153.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000282.jpg'>
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/PIL/Image.py:984: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# cannot identify image file <_io.BufferedReader name='images/sports/00000197.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000092.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000359.png'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000363.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000435.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000414.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000450.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000196.png'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000366.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000340.jpg'>
# cannot identify image file <_io.BufferedReader name='images/sports/00000410.jpeg'>

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder('images', train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
(data.classes, data.c, len(data.train_ds), len(data.valid_ds))
# Out:
# (['formal', 'sports'], 2, 846, 211)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %% [markdown]
# # Learning

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/ec2-user/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:02, 40562786.57it/s]

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5)
#     (8): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
# %%time
learn.fit_one_cycle(4)
# Out:
# Total time: 00:40 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.783409</td>
#       <td>0.369269</td>
#       <td>0.170616</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.636355</td>
#       <td>0.402014</td>
#       <td>0.170616</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.549865</td>
#       <td>0.379841</td>
#       <td>0.146919</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.489768</td>
#       <td>0.375525</td>
#       <td>0.127962</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 14.7 s, sys: 8.1 s, total: 22.8 s
# Wall time: 40.3 s

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (846 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# sports,sports,sports,sports,sports
# Path: images;
#
# Valid: LabelList (211 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# sports,formal,formal,formal,sports
# Path: images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5)
#     (8): Linear(in_features=512, out_features=2, bias=True)
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function error_rate at 0x7ff08c0c8840>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('images'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True)], callbacks=[], layer_groups=[Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU(inplace)
#   (7): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU(inplace)
#   (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU(inplace)
#   (17): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (20): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (21): ReLU(inplace)
#   (22): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (25): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (27): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (28): ReLU(inplace)
#   (29): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (30): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (31): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (32): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (33): ReLU(inplace)
#   (34): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (35): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (37): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (38): ReLU(inplace)
#   (39): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace)
#   (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU(inplace)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): ReLU(inplace)
#   (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace)
#   (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (23): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (24): ReLU(inplace)
#   (25): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (26): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (27): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (28): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace)
#   (30): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (33): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (34): ReLU(inplace)
#   (35): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (36): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (37): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (39): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (40): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (41): ReLU(inplace)
#   (42): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (43): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (44): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (45): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (46): ReLU(inplace)
#   (47): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (48): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), Sequential(
#   (0): AdaptiveAvgPool2d(output_size=1)
#   (1): AdaptiveMaxPool2d(output_size=1)
#   (2): Flatten()
#   (3): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): Dropout(p=0.25)
#   (5): Linear(in_features=1024, out_features=512, bias=True)
#   (6): ReLU(inplace)
#   (7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): Dropout(p=0.5)
#   (9): Linear(in_features=512, out_features=2, bias=True)
# )], add_time=True)

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=3)
# Out:
# [('sports', 'formal', 16), ('formal', 'sports', 11)]

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 00:23 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.387744</td>
#       <td>0.366456</td>
#       <td>0.146919</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.381468</td>
#       <td>0.366514</td>
#       <td>0.142180</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Cleaning Up data

# %%
from fastai.widgets import *

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ds
# Out:
# LabelList (846 items)
# x: ImageList
# Image (3, 250, 300),Image (3, 250, 300),Image (3, 250, 300),Image (3, 250, 300),Image (3, 250, 300)
# y: CategoryList
# sports,sports,sports,sports,sports
# Path: images

# %%
#idxs

# %%
ImageCleaner(ds, idxs, Path('images'))
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
data = ImageDataBunch.from_csv(path="images", csv_labels='cleaned.csv', valid_pct=0.2, bs=32,
                               ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (677 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# sports,sports,sports,sports,sports
# Path: images;
#
# Valid: LabelList (169 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# formal,formal,formal,formal,formal
# Path: images;
#
# Test: None

# %%
data.classes, data.c
# Out:
# (['formal', 'sports'], 2)

# %%
data.batch_size
# Out:
# 32

# %%
data.show_batch()

# %%
fnames = get_image_files('data/sports')
fnames[:5]
# Out:
# []

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-05))
# Out:
# Total time: 01:52 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.985666</td>
#       <td>0.799925</td>
#       <td>0.550296</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.953158</td>
#       <td>0.789463</td>
#       <td>0.461538</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.921777</td>
#       <td>0.737103</td>
#       <td>0.455621</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.867981</td>
#       <td>0.681912</td>
#       <td>0.372781</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.841299</td>
#       <td>0.664086</td>
#       <td>0.343195</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.815886</td>
#       <td>0.642192</td>
#       <td>0.313609</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.804963</td>
#       <td>0.640571</td>
#       <td>0.319527</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.782950</td>
#       <td>0.642620</td>
#       <td>0.343195</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1-50')

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(3, max_lr=slice(1e-6))
# Out:
# Total time: 00:53 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.753654</td>
#       <td>0.642388</td>
#       <td>0.343195</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.734626</td>
#       <td>0.636738</td>
#       <td>0.319527</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.740618</td>
#       <td>0.634644</td>
#       <td>0.319527</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
